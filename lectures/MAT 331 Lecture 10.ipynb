# %%
def gcdUsingEuclidean(a,b):
  x = min(a,b)
  y = max(a,b) 
  while x > 0:
    y, x = x, y % x
  return y

# %%
gcdUsingEuclidean(232, 136)
# Out:
# 8

# %%
def xgcd(a, b):
  x = min(a,b)
  y = max(a,b)
  eq_list = []
  
  while x > 0:
    d = y//x
    r = y % x
    eq_list.append((y, x, d, r))
    y, x = x, r

# to calculate integer solutions for a*m + b*n = gcd
  m = 0
  n = 0 
  gcd_eq = eq_list.pop()

  while eq_list:
    current = eq_list.pop()
    m = 1
    n = current[2]

  return eq_list

# %%
xgcd(232, 136)
# Out:
# [(232, 136, 1, 96),
#  (136, 96, 1, 40),
#  (96, 40, 2, 16),
#  (40, 16, 2, 8),
#  (16, 8, 2, 0)]

# %%
'''
a = l[0]
b = l[1]

l[0] = l[1]*fact1 + l[2]
l[1] = l[2]*fact2 + l[3]
l[2] = l[3]*fact3 + l[4]
l[3] = l[4]*fact4 + gcd
l[4] = gcd*fact5

m = 0
n = 0

l[3]-l[4]*d4 = gcd
m = 1
n = -d4
l[3]*m + l[4]*n = gcd
  l[4] = l[2]-l[3]*d3
l[3]*m-(l[2]-l[3]*d3)*n = gcd
l[3]*m+l[3]*d3*n-l[2]*n = gcd
l[3]*(m+d3*n)-l[2]*n = gcd
m = m+d3*n
n = -n
l[3]*m + l[2]*n = gcd
  l[3] = l[1]-l[2]*d2
(l[1]-l[2]*d2)*m + l[2]*n = gcd
l[1]*m-l[2]*d2*m+l[2]*n = gcd
l[1]*m+l[2]*(n-m*d2) = gcd
m = m
n = n-m*d2
l[1]*m + l[2]*n = gcd

'''
