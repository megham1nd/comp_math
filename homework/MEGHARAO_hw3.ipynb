# %% [markdown]
# ### HW3
# ### These are based on the solutions I posted for lecture 7.
#
# ### https://colab.research.google.com/drive/1lD7wjEC-u41bpjkqp8RuFl2qPNFBkTH8?usp=sharing
#
#
# 1. A student has tried to work through the code when listprimes(8) is called. Here is the submission:
# Go through the code line by line and find the mistake(s).

# %%
'''
n=8
isPrime = [True, True, True, True, True, True, True, True, True] 
isPrime = [False, True, True, True, True, True, True, True, True]
isPrime = [False, False, True, True, True, True, True, True, True]
for divisor in [2, 3, 4, 5, 6, 7, 8]:
  divisor = 2
    multiple = 4
    while multiple <= 8:
      isPrime = [False, False, True, True, False, True, True, True, True]
      multiple = 6
        isPrime = [False, False, True, True, False, True, False, True, True]
      multiple = 8
        isPrime = [False, False, True, True, False, True, False, True, False]
      multiple = 10 
  divisor = 3
    multiple = 6
    while multiple <= 8:
      isPrime = [False, False, True, True, False, True, False, True, False]
      multiple = 9
    multiple = 10 ## MULTIPLE DOES NOT GO UP TO 10, STOPS AT 9 > 8
  ## MISSING divisor = 4
  divisor = 5
    multiple = 10
    while muiltiple <= 8:
  divisor = 6
    multiple = 12
    while multiple <= 8:
  divisor = 7
    multiple = 14
    while multiple <= 8:
  divisor = 8
    multiple = 16
    while multiple <= 8:
  

  primes = []
  i = 0
  for i in [0,1,2,3,4,5,6,7,8]:
    isPrime[0] is False
    isPrime[1] is False
    isPrime[2] is True:
      primes = [2]
    isPrime[3] is True
      primes = [2,3]
    isPrime[4] is False
    isPrime[5] is True
      primes = [2,3,5]
    isPrime[6] is False
    isPrime[7] is True
      primes = [2,3,5,7]
    isPrime[8] is False

  return [2,3,5,7]
'''

# %% [markdown]
# 2. Now it's your turn to work through the code, for primeFactors(20). Do it in the same style as the submission in Q1 above.
# The first two lines have been written for you.
# You can use either version of the solutions I wrote.

# %%
def primeFactors(n):
  primes = listprimes(n)
  factors = []
  remainder = n
  for prime in primes:
    while remainder % prime == 0:
      factors.append(prime)
      remainder = remainder/prime 
  return factors

'''
n = 20
primes = [2,3,5,7,11,13,17,19]
factors = []
remainder = 20

for prime in [2,3,5,7,11,13,17,19]:
  prime = 2
    while 20 % 2 == 0:
      factors = [2]
      remainder = 20/2 = 10
    while 10 % 2 == 0:
      factors = [2, 2]
      remainder = 10/2 = 5
    while 5 % 2 == 0:
  prime = 3
    while 5 % 3 == 0:
  prime = 5
    while 5 % 5 == 0:
      factors = [2, 2, 5]
      remainder = 5/5 = 1
    while 1 % 5 == 0:
  prime = 7
    while 1 % 7 == 0:
  prime = 11
    while 1 % 11 == 0:
  prime = 13
    while 1 % 13 == 0:
  prime = 17
    while 1 % 17 == 0:
  prime = 19
    while 1 % 19 == 0:

return [2, 2, 5]
'''

# %% [markdown]
# 3. Do the same for gcdUsingEuclidean(21,13). You can use either version of the solutions I wrote.

# %%
def gcdUsingEuclidean(a,b):
  x = min(a,b)
  y = max(a,b) 
  while x > 0:
    y, x = x, y % x
  return y

'''
a = 21
b = 13
x = 13
y = 21

while 13 > 0:
  y = 13
  x = 21 % 13 = 8
while 8 > 0:
  y = 8
  x = 13 % 8 = 5
while 5 > 0:
  y = 5
  x = 8 % 5 = 3
while 3 > 0:
  y = 3
  x = 5 % 3 = 2
while 2 > 0:
  y = 2
  x = 3 % 2 = 1
while 1 > 0:
  y = 1
  x = 2 % 1 = 0
while 0 > 0:

return 1
'''

# %% [markdown]
# 4. Do the same for gcdUsingFactorization(140, 120). You may assume that the output of primeFactors(140) is [2,2,5,7] and the output of primeFactors(12) is [2,2,2,3,5].

# %%
def gcdUsingFactorization(a,b):
  '''
    Assume that primeFactors(a) returns 
    the list of prime factors of a
    in ascending order
  '''
  gcd = 1
  factors_a = primeFactors(a)
  factors_b = primeFactors(b)
  i=0
  j=0
  while i < len(factors_a) and j < len(factors_b):
    factor_a = factors_a[i]
    factor_b = factors_b[j]
    if factor_a == factor_b:
      gcd = gcd * factor_a
      i += 1
      j += 1
    elif factor_a < factor_b:
      i += 1
    elif factor_a > factor_b:
      j += 1 
  return gcd

'''
a = 140
b = 120
gcd = 1
factors_a = [2, 2, 5, 7]
factors_b = [2, 2, 2, 3, 5]
i = 0
j = 0

while 0 < 4 and 0 < 5:
  factor_a = 2
  factor_b = 2
  if 2 == 2:
    gcd = 1 * 2 = 2
    i = 1
    j = 1
  elif 2 < 2:
  elif 2 > 2:
while 1 < 4 and 1 < 5:
  factor_a = 2
  factor_b = 2
  if 2 == 2:
    gcd = 2 * 2 = 4
    i = 2
    j = 2
  elif 2 < 2:
  elif 2 > 2:
while 2 < 4 and 2 < 5:
  factor_a = 5
  factor_b = 2
  if 5 == 2:
  elif 5 < 2:
  elif 5 > 2:
    j = 3
while 2 < 4 and 3 < 5:
  factor_a = 5
  factor_b = 3
  if 5 == 3:
  elif 5 < 3:
  elif 5 > 3:
    j = 4
while 2 < 4 and 4 < 5:
  factor_a = 5
  factor_b = 5
  if 5 == 5:
    gcd = 4 * 5 = 20
    i = 3
    j = 5
  elif 5 < 5:
  elif 5 > 5:
while 3 < 4 and 5 < 5:

return 20
'''

# %% [markdown]
# 5. Do the same for vignere_encrypt2('cad', 'autom'), where vignere_encrypt2 is the code below. You may
# assume that letters_to_indices = {'a':0, 'b':1, 'c':2, ...} has already been defined.
#
# ```python
# def vignere_encrypt2(key, data):
#   alphabet = 'abcdefghijklmnopqrstuvwxyz'
#   output = ''
#   i = 0
#   for letter in data:
#     index = letters_to_indices[letter]
#     shift = letters_to_indices[key[i % len(key)]]
#     new_letter = alphabet[(index + shift) % 26]
#     output = output + new_letter
#     i = i + 1
#   return output
# ```

# %%
'''
key = 'cad'
data = 'autom'
output = ''
i = 0

for letter in 'autom':
  letter = 'a'
    index = letters_to_indices['a'] = 0
    shift = letters_to_indices['cad'[0 % 3]] = letters_to_indices['cad'[0]] = letters_to_indices['c'] = 2
    new_letter = alphabet[(0+3) % 26] = alphabet[3 % 26] = alphabet[3] = 'd'
    output = 'd'
    i = 1
  letter = 'u'
    index = letters_to_indices['u'] = 20
    shift = letters_to_indices['cad'[1 % 3]] = letters_to_indices['cad'[1]] = letters_to_indices['a'] = 0
    new_letter = alphabet[(20+0) % 26] = alphabet[20 % 26] = alphabet[20] = 'u'
    output = 'du'
    i = 2
  letter = 't'
    index = letters_to_indices['t'] = 19
    shift = letters_to_indices['cad'[2 % 3]] = letters_to_indices['cad'[2]] = letters_to_indices['d'] = 3
    new_letter = alphabet[(19+3) % 26] = alphabet[22 % 26] = alphabet[22] = 'w'
    output = 'duw'
    i = 3
  letter = 'o'
    index = letters_to_indices['o'] = 14
    shift = letters_to_indices['cad'[3 % 3]] = letters_to_indices['cad'[0]] = letters_to_indices['c'] = 2
    new_letter = alphabet[(14+2) % 26] = alphabet[16 % 26] = alphabet[16] = 'q'
    output = 'duwq'
    i = 4
  letter = 'm'
    index = letters_to_indices['m'] = 12
    shift = letters_to_indices['cad'[4 % 3]] = letters_to_indices['cad'[1]] = letters_to_indices['a'] = 0
    new_letter = alphabet[(12+0) % 26] = alphabet[12 % 26] = alphabet[12] = 'm'
    output = 'duwqm'
    i = 5

return 'duwqm'
'''

# %% [markdown]
# 6. Do the same for vignere_decrypt2('cad','autom'), where vignere_decrypt2 is the code below.
# You should also show the working for the vignere_encrypt2
# that is called within this function.
# ```
# def vignere_decrypt2(key, encrypted):
#   inverse_key = ''
#   for c in key:
#     inverse_c = alphabet[26-letters_to_indices[c]]
#     inverse_key += inverse_c
#
#   return vignere_encrypt2(inverse_key, encrypted)
# ```

# %%
'''
key = 'cad'
encrypted = 'autom'
inverse key = ''

for c in 'cad':
  c = 'c'
    inverse_c = alphabet[26-letters_to_indices['c']] = alphabet[26-2] = alphabet[24] = 'y'
    inverse_key = 'y'
  c = 'a'
    inverse_c = alphabet[26-letters_to_indices['a']] = alphabet[26-0] = alphabet[26]
    ## OUT OF BOUNDS ERROR - alphabet only has index up to 25
    ## CODE SHOULD READ: inverse_c = alphabet[(26-letters_to_indices[c]) % 26]
'''
